# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv("C:\\Users\\SHADOS BOXS\\Desktop\\Excel\\project\\diabetic_data.csv",na_values=["?"])
# Out:
# C:\Users\SHADOS BOXS\AppData\Local\Temp\ipykernel_2904\564501217.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("C:\\Users\\SHADOS BOXS\\Desktop\\Excel\\project\\diabetic_data.csv",na_values=["?"])

# %%
b = sns.countplot(x = 'admission_source_id',data = df)

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      99493 non-null   object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    3197 non-null    object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                61510 non-null   object
#  11  medical_specialty         51817 non-null   object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...

# %%
df['race'].mode()
# Out:
# 0    Caucasian
# Name: race, dtype: object

# %%
df['race'].fillna('Caucasian',inplace=True)

# %%
df.isnull().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                            0
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...

# %%
df.drop('weight',axis = 1,inplace=True)

# %%
df.drop('diag_1',axis = 1,inplace=True)

# %%
df.drop('diag_2',axis = 1,inplace=True)

# %%
df.drop('diag_3',axis = 1,inplace=True)

# %%
df.drop('citoglipton',axis = 1,inplace=True)

# %%
df.drop('examide',axis = 1,inplace=True)

# %%
df.isnull().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# rosiglitazone               0
# ...

# %%
df['payer_code'].mode()
# Out:
# 0    MC
# Name: payer_code, dtype: object

# %%
df['payer_code'].fillna('MC',inplace=True)

# %%
df['medical_specialty'].mode()
# Out:
# 0    InternalMedicine
# Name: medical_specialty, dtype: object

# %%
df['medical_specialty'].fillna('InternalMedicine',inplace=True)

# %%
df.isnull().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# rosiglitazone               0
# ...

# %%
#from sklearn.preprocessing import LabelEncoder

# %%
#le = LabelEncoder()

# %%
#label = le.fit_transform(df['race'])

# %%
#label

# %%
#le.classes_

# %%
#Data = df.drop('race',axis=1)

# %%
#Data['race'] = label

# %%
#Data

# %%
df.describe(include="all")
# Out:
#         encounter_id   patient_nbr       race  gender      age  \
# count   1.017660e+05  1.017660e+05     101766  101766   101766
# unique           NaN           NaN          5       3       10
# top              NaN           NaN  Caucasian  Female  [70-80)
# freq             NaN           NaN      78372   54708    26068
# mean    1.652016e+08  5.433040e+07        NaN     NaN      NaN
# std     1.026403e+08  3.869636e+07        NaN     NaN      NaN
# min     1.252200e+04  1.350000e+02        NaN     NaN      NaN
# 25%     8.496119e+07  2.341322e+07        NaN     NaN      NaN
# 50%     1.523890e+08  4.550514e+07        NaN     NaN      NaN
# 75%     2.302709e+08  8.754595e+07        NaN     NaN      NaN
# max     4.438672e+08  1.895026e+08        NaN     NaN      NaN
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# count       101766.000000             101766.000000        101766.000000
# ...

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
sns.boxplot(x=df['admission_type_id'])
# Out:
# <AxesSubplot:xlabel='admission_type_id'>

# %%
sns.boxplot(x=df['discharge_disposition_id'])
# Out:
# <AxesSubplot:xlabel='discharge_disposition_id'>

# %%
sns.boxplot(x=df['admission_source_id'])
# Out:
# <AxesSubplot:xlabel='admission_source_id'>

# %%
sns.boxplot(x=df['time_in_hospital'])
# Out:
# <AxesSubplot:xlabel='time_in_hospital'>

# %%
sns.boxplot(x=df['num_lab_procedures'])
# Out:
# <AxesSubplot:xlabel='num_lab_procedures'>

# %%
sns.boxplot(x=df['num_procedures'])
# Out:
# <AxesSubplot:xlabel='num_procedures'>

# %%
sns.boxplot(x=df['num_medications'])
# Out:
# <AxesSubplot:xlabel='num_medications'>

# %%
sns.boxplot(x=df['number_outpatient'])
# Out:
# <AxesSubplot:xlabel='number_outpatient'>

# %%
sns.boxplot(x=df['number_emergency'])
# Out:
# <AxesSubplot:xlabel='number_emergency'>

# %%
sns.boxplot(x=df['number_inpatient'])
# Out:
# <AxesSubplot:xlabel='number_inpatient'>

# %%
sns.boxplot(x=df['number_diagnoses'])
# Out:
# <AxesSubplot:xlabel='number_diagnoses'>

# %%
#plt.figure(figsize=(16,9))
b = sns.countplot(x = 'race',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
b = sns.countplot(x = 'gender',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'age',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'admission_type_id',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
b = sns.countplot(x = 'change',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
b = sns.countplot(x = 'readmitted',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
b = sns.countplot(x = 'diabetesMed',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
b = sns.countplot(x = 'metformin',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'discharge_disposition_id',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'number_diagnoses',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'admission_source_id',data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.bar("gender","readmitted",data=df)
# Out:
# <BarContainer object of 101766 artists>

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'number_emergency',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'number_outpatient',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'number_inpatient',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
sns.barplot(data=df,x="diabetesMed",hue="readmitted",y="num_medications")
# Out:
# <AxesSubplot:xlabel='diabetesMed', ylabel='num_medications'>

# %%
sns.barplot(data=df,x="num_lab_procedures",hue="readmitted",y="change")
# Out:
# <AxesSubplot:xlabel='num_lab_procedures', ylabel='change'>

# %%
sns.barplot(data=df,x="num_procedures",hue="readmitted",y="change")
for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'age',hue="diabetesMed",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'gender',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'age',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'diabetesMed',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'payer_code',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(20,9))
b = sns.countplot(x = 'medical_specialty',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
sns.barplot(data=df,x="time_in_hospital",hue="readmitted",y="medical_specialty")
# Out:
# <AxesSubplot:xlabel='time_in_hospital', ylabel='medical_specialty'>

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'change',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'gender',hue="diabetesMed",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
b = sns.countplot(x = 'num_medications',hue="readmitted",data = df)

for bars in b.containers:
    b.bar_label(bars)

# %%
a=df.corr()
a
# Out:
#                           encounter_id  patient_nbr  admission_type_id  \
# encounter_id                  1.000000     0.512028          -0.158961
# patient_nbr                   0.512028     1.000000          -0.011128
# admission_type_id            -0.158961    -0.011128           1.000000
# discharge_disposition_id     -0.132876    -0.136814           0.083483
# admission_source_id          -0.112402    -0.032568           0.106654
# time_in_hospital             -0.062221    -0.024092          -0.012500
# num_lab_procedures           -0.026062     0.015946          -0.143713
# num_procedures               -0.014225    -0.015570           0.129888
# num_medications               0.076113     0.020665           0.079535
# number_outpatient             0.103756     0.103379           0.026511
# number_emergency              0.082803     0.062352          -0.019116
# number_inpatient              0.030962     0.012480          -0.038161
# ...

# %%
sns.heatmap(a)
# Out:
# <AxesSubplot:>
